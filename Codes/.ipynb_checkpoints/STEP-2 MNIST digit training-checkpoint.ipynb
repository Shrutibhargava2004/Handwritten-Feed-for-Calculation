# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
mnist = keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
plt.figure(figsize=(10,15))

for i in range(20):  # Display first 10 images
    plt.subplot(10, 10, i + 1)
    plt.imshow(X_train[i], cmap='gray')  # Display in grayscale
    plt.title(f"Label: {y_train[i]}")
    plt.axis('off')

plt.show()

# %%
model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),  
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Flatten(),  
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dense(10, activation='softmax')  
])
# Out:
# D:\Sem - 6\Minor 2\env\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train.reshape(-1, 28, 28, 1), y_train, epochs=10, validation_data=(X_test.reshape(-1, 28, 28, 1), y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9081 - loss: 0.2948 - val_accuracy: 0.9798 - val_loss: 0.0634
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9858 - loss: 0.0463 - val_accuracy: 0.9879 - val_loss: 0.0373
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9903 - loss: 0.0288 - val_accuracy: 0.9886 - val_loss: 0.0353
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9935 - loss: 0.0201 - val_accuracy: 0.9896 - val_loss: 0.0347
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9951 - loss: 0.0151 - val_accuracy: 0.9900 - val_loss: 0.0355
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9964 - loss: 0.0112 - val_accuracy: 0.9925 - val_loss: 0.0263
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9974 - loss: 0.0086 - val_accuracy: 0.9913 - val_loss: 0.0325
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.9979 - loss: 0.0058 - val_accuracy: 0.9881 - val_loss: 0.0483
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9978 - loss: 0.0070 - val_accuracy: 0.9906 - val_loss: 0.0358
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9990 - loss: 0.0030 - val_accuracy: 0.9899 - val_loss: 0.0398

# %%
test_loss, test_acc = model.evaluate(X_test.reshape(-1, 28, 28, 1), y_test)
print(f"\nTest Accuracy: {test_acc * 100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9879 - loss: 0.0492
#
# Test Accuracy: 98.99%

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 11, 11, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 675,104 (2.58 MB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 450,070 (1.72 MB)

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

y_pred = model.predict(X_test.reshape(-1, 28, 28, 1))
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
accuracy = accuracy_score(y_test, y_pred_classes)
print(f'Accuracy: {accuracy}')

precision = precision_score(y_test, y_pred_classes, average='macro')
print(f'Precision: {precision}')

recall = recall_score(y_test, y_pred_classes, average='macro')
print(f'Recall: {recall}')

f1 = f1_score(y_test, y_pred_classes, average='macro')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.9899
# Precision: 0.9899343035692623
# Recall: 0.9898909815595859
# F1 Score: 0.9898874342072119

# %%
import seaborn as sns

cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred_classes))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       980
#            1       0.99      1.00      0.99      1135
#            2       1.00      0.97      0.99      1032
#            3       0.98      0.99      0.99      1010
#            4       0.99      0.99      0.99       982
#            5       0.98      0.99      0.99       892
#            6       1.00      0.99      0.99       958
#            7       0.99      0.99      0.99      1028
#            8       0.99      0.99      0.99       974
#            9       0.99      0.99      0.99      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %%
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plot Training and Validation Loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
model.save("digit_recognition_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Real time digit prediction

# %%
import cvzone
import cv2
import numpy as np
from cvzone.HandTrackingModule import HandDetector
from tensorflow.keras.models import load_model

# Load the trained model (Make sure it's already trained and available)
model_path = "digit_recognition_model.h5"  # Replace with your actual trained model file
model = load_model(model_path)

# Video Capture Settings
cap = cv2.VideoCapture(0)

# Hand Detector
detector = HandDetector(staticMode=False, maxHands=1, modelComplexity=1, detectionCon=0.5, minTrackCon=0.5)

def getHandInfo(img):
    hands, img = detector.findHands(img, draw=True, flipType=True)
    if hands:
        hand = hands[0]  # Get the first hand detected
        lmList = hand["lmList"]  # List of 21 landmarks for the first hand
        fingers = detector.fingersUp(hand)
        return fingers, lmList
    return None

def draw(info, prev_pos, canvas):
    fingers, lmList = info
    current_pos = None 
    if fingers == [0, 1, 0, 0, 0]:  # Index finger up
        current_pos = lmList[8][0:2]  # Index finger tip coordinates
        if prev_pos is None: 
            prev_pos = current_pos
        cv2.line(canvas, tuple(current_pos), tuple(prev_pos), (255, 255, 255), 10)  # White color for high contrast
    return current_pos, canvas

def preprocess_for_prediction(canvas):
    """ Preprocess the drawn image for model prediction. """
    # Convert to grayscale
    gray_canvas = cv2.cvtColor(canvas, cv2.COLOR_BGR2GRAY)
    
    # Apply binary thresholding
    _, binary = cv2.threshold(gray_canvas, 50, 255, cv2.THRESH_BINARY)
    
    # Find bounding box of the digit
    y_indices, x_indices = np.where(binary > 0)
    if len(y_indices) > 0 and len(x_indices) > 0:
        x_min, x_max = x_indices.min(), x_indices.max()
        y_min, y_max = y_indices.min(), y_indices.max()
        cropped = binary[y_min:y_max+1, x_min:x_max+1]
    else:
        return None  # No valid digit detected
    
    # Resize while maintaining aspect ratio
    h, w = cropped.shape
    aspect_ratio = w / h

    if aspect_ratio > 1:
        new_w = 20
        new_h = int(20 / aspect_ratio)
    else:
        new_h = 20
        new_w = int(20 * aspect_ratio)

    resized = cv2.resize(cropped, (new_w, new_h), interpolation=cv2.INTER_AREA)

    # Center the digit in a 28x28 blank image
    final_img = np.zeros((28, 28), dtype=np.uint8)
    x_offset = (28 - new_w) // 2
    y_offset = (28 - new_h) // 2
    final_img[y_offset:y_offset+new_h, x_offset:x_offset+new_w] = resized

    # Normalize and reshape for model input
    final_img = final_img / 255.0
    final_img = final_img.reshape(1, 28, 28, 1)  # Shape required for CNN

    return final_img

prev_pos = None
canvas = None
predicted_class = None

while True:
    success, img = cap.read()
    img = cv2.flip(img, 1)  # Mirror effect for better drawing experience
    
    if canvas is None:
        canvas = np.zeros_like(img)
    
    info = getHandInfo(img)
    if info:
        fingers, lmList = info
        
        # Clear canvas when all 5 fingers are up
        if fingers == [1, 1, 1, 1, 1]:  
            canvas = np.zeros_like(img)
            prev_pos = None
            predicted_class = None
            print("Canvas Cleared (All 5 Fingers Up)")

        # Predict digit when 2nd & 5th fingers are up
        if fingers == [0, 1, 0, 0, 1]:
            processed_img = preprocess_for_prediction(canvas)
            if processed_img is not None:
                prediction = model.predict(processed_img)
                predicted_class = np.argmax(prediction)
                confidence = np.max(prediction) * 100
                print(f"Predicted: {predicted_class} ({confidence:.2f}%)")

        prev_pos, canvas = draw(info, prev_pos, canvas)

    # Overlay canvas on image
    image_combined = cv2.addWeighted(img, 0.7, canvas, 0.3, 0)

    # Display prediction on screen
    if predicted_class is not None:
        cv2.putText(image_combined, f'Predicted: {predicted_class}', 
                    (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 0), 3)
    
    # Show windows
    cv2.imshow("Canvas", canvas)
    cv2.imshow("Real-Time Prediction", image_combined)

    # Quit when 'Q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Predicted: 8 (96.19%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted: 8 (96.19%)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Predicted: 1 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Predicted: 1 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Predicted: 1 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Predicted: 1 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Predicted: 1 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Predicted: 1 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Predicted: 1 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Predicted: 1 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Predicted: 1 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Predicted: 1 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Predicted: 1 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted: 1 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Predicted: 1 (100.00%)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Predicted: 9 (70.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Predicted: 9 (70.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Predicted: 9 (70.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Predicted: 9 (70.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Predicted: 9 (70.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Predicted: 9 (70.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Predicted: 9 (70.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Predicted: 9 (70.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Predicted: 9 (70.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Predicted: 9 (70.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Predicted: 9 (70.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Predicted: 9 (70.50%)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted: 2 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Predicted: 2 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Predicted: 2 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Predicted: 2 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Predicted: 2 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Predicted: 2 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Predicted: 2 (100.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Predicted: 2 (100.00%)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Predicted: 4 (58.74%)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# Canvas Cleared (All 5 Fingers Up)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Predicted: 4 (99.20%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
